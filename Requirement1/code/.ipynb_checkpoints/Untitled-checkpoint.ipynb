# %%
import pandas as pd
# Out:
# C:\Users\14629\anaconda3\envs\tensorflow\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\14629\anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\14629\anaconda3\envs\tensorflow\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
product='pacifier'#hair_dryer microwave pacifier
train=pd.read_csv(product+'.tsv', sep='\t', header=0)

# %%
train
# Out:
#       marketplace  customer_id       review_id  product_id  product_parent  \
# 0              US     40626522  R1A3ZUBR8TSAKY  B00793CZAE       572944212
# 1              US     16290022   RLJNYBK4FGBYX  B003PCYMP4       911821018
# 2              US     10216509  R26QCW75C4JDOK  B003CK3LDI       392768822
# 3              US       114040  R2E7N0TVLUHUDR  B003CK3LDI       392768822
# 4              US     27971579  R1SO9VMCIGZX3U  B003PCYMP4       911821018
# ...           ...          ...             ...         ...             ...
# 18934          US     21573136  R3BWX9SX2KS651  B00007C65S        51313971
# 18935          US     19606706  R38BZDRPIX74RX  B00007C65S        51313971
# 18936          US     25764155  R1XNX6XGDIHJ7G  B00007C65S        51313971
# 18937          US     28162301  R1TW1Z1I35H29N  B00007C65S        51313971
# 18938          US     40173284  R2AAZF8OIGDT7T  B00007C65S        51313971
#
#                                            product_title product_category  \
# 0               mary meyer wubbanub plush pacifier, lamb             Baby
# 1                          wubbanub lamb infant pacifier             Baby
# 2                     wubbanub infant pacifier - giraffe             Baby
# 3                     wubbanub infant pacifier - giraffe             Baby
# 4                          wubbanub lamb infant pacifier             Baby
# ...                                                  ...              ...
# 18934  munchkin deluxe bottle  and food warmer with p...             Baby
# 18935  munchkin deluxe bottle  and food warmer with p...             Baby
# 18936  munchkin deluxe bottle  and food warmer with p...             Baby
# 18937  munchkin deluxe bottle  and food warmer with p...             Baby
# 18938  munchkin deluxe bottle  and food warmer with p...             Baby
#
#        star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0                5              0            0    N                 Y
# 1                5              0            0    N                 Y
# 2                5              0            0    N                 Y
# 3                5              0            0    N                 Y
# 4                5              0            0    N                 Y
# ...            ...            ...          ...  ...               ...
# 18934            2              0            0    N                 N
# 18935            4              1            1    N                 N
# 18936            5              0            0    N                 N
# 18937            1              2            2    N                 N
# 18938            2              0            0    N                 N
#
#                     review_headline  \
# 0                        Love this!
# 1                            Love 💕
# 2                        Five Stars
# 3                        Five Stars
# 4                        Five Stars
# ...                             ...
# 18934         Not for bottle liners
# 18935            good enough for me
# 18936                    I love it!
# 18937               save your money
# 18938  Always makes bottles too hot
#
#                                              review_body review_date
# 0      Perfect match for the Gund Huggybuddy I bought...   8/31/2015
# 1             My little girl love this paci contraption!   8/31/2015
# 2      My son loves this one and will only sleep if h...   8/31/2015
# 3                                                Perfect   8/31/2015
# 4                       Amazing addition to the nursery!   8/31/2015
# ...                                                  ...         ...
# 18934  We have been using the bottle warmer and have ...   5/24/2004
# 18935  This isn't the greatest product ever invented,...    4/4/2004
# 18936  I love this bottle warmer.  After researching ...    4/4/2004
# 18937  I finally broke down and opened this shower gi...   12/2/2003
# 18938  We bought this bottle warmer two weeks ago bec...   4/27/2003
#
# [18939 rows x 15 columns]

# %%
# 删除无关字段
train=train.drop(columns=['marketplace','customer_id','review_id','product_id','product_category'])
train['product_title'] = train['product_title'].str.lower()
# 将“n","y"转换成”0","1"
train.replace('n','0',inplace=True)
train.replace('y','1',inplace=True)
train.replace('N','0',inplace=True)
train.replace('Y','1',inplace=True)
# 将字符串类型的数据转换成float
train[['star_rating','helpful_votes','total_votes','vine','verified_purchase']]\
    =train[['star_rating','helpful_votes','total_votes','vine','verified_purchase']].astype('float')

# %%
train
# Out:
#        product_parent                                      product_title  \
# 0           572944212           mary meyer wubbanub plush pacifier, lamb
# 1           911821018                      wubbanub lamb infant pacifier
# 2           392768822                 wubbanub infant pacifier - giraffe
# 3           392768822                 wubbanub infant pacifier - giraffe
# 4           911821018                      wubbanub lamb infant pacifier
# ...               ...                                                ...
# 18934        51313971  munchkin deluxe bottle  and food warmer with p...
# 18935        51313971  munchkin deluxe bottle  and food warmer with p...
# 18936        51313971  munchkin deluxe bottle  and food warmer with p...
# 18937        51313971  munchkin deluxe bottle  and food warmer with p...
# 18938        51313971  munchkin deluxe bottle  and food warmer with p...
#
#        star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0              5.0            0.0          0.0   0.0                1.0
# 1              5.0            0.0          0.0   0.0                1.0
# 2              5.0            0.0          0.0   0.0                1.0
# 3              5.0            0.0          0.0   0.0                1.0
# 4              5.0            0.0          0.0   0.0                1.0
# ...            ...            ...          ...   ...                ...
# 18934          2.0            0.0          0.0   0.0                0.0
# 18935          4.0            1.0          1.0   0.0                0.0
# 18936          5.0            0.0          0.0   0.0                0.0
# 18937          1.0            2.0          2.0   0.0                0.0
# 18938          2.0            0.0          0.0   0.0                0.0
#
#                     review_headline  \
# 0                        Love this!
# 1                            Love 💕
# 2                        Five Stars
# 3                        Five Stars
# 4                        Five Stars
# ...                             ...
# 18934         Not for bottle liners
# 18935            good enough for me
# 18936                    I love it!
# 18937               save your money
# 18938  Always makes bottles too hot
#
#                                              review_body review_date
# 0      Perfect match for the Gund Huggybuddy I bought...   8/31/2015
# 1             My little girl love this paci contraption!   8/31/2015
# 2      My son loves this one and will only sleep if h...   8/31/2015
# 3                                                Perfect   8/31/2015
# 4                       Amazing addition to the nursery!   8/31/2015
# ...                                                  ...         ...
# 18934  We have been using the bottle warmer and have ...   5/24/2004
# 18935  This isn't the greatest product ever invented,...    4/4/2004
# 18936  I love this bottle warmer.  After researching ...    4/4/2004
# 18937  I finally broke down and opened this shower gi...   12/2/2003
# 18938  We bought this bottle warmer two weeks ago bec...   4/27/2003
#
# [18939 rows x 10 columns]

# %%
train['product_parent']=train['product_parent'].astype('object')

# %%
train
# Out:
#       product_parent                                      product_title  \
# 0          572944212           mary meyer wubbanub plush pacifier, lamb
# 1          911821018                      wubbanub lamb infant pacifier
# 2          392768822                 wubbanub infant pacifier - giraffe
# 3          392768822                 wubbanub infant pacifier - giraffe
# 4          911821018                      wubbanub lamb infant pacifier
# ...              ...                                                ...
# 18934       51313971  munchkin deluxe bottle  and food warmer with p...
# 18935       51313971  munchkin deluxe bottle  and food warmer with p...
# 18936       51313971  munchkin deluxe bottle  and food warmer with p...
# 18937       51313971  munchkin deluxe bottle  and food warmer with p...
# 18938       51313971  munchkin deluxe bottle  and food warmer with p...
#
#        star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0              5.0            0.0          0.0   0.0                1.0
# 1              5.0            0.0          0.0   0.0                1.0
# 2              5.0            0.0          0.0   0.0                1.0
# 3              5.0            0.0          0.0   0.0                1.0
# 4              5.0            0.0          0.0   0.0                1.0
# ...            ...            ...          ...   ...                ...
# 18934          2.0            0.0          0.0   0.0                0.0
# 18935          4.0            1.0          1.0   0.0                0.0
# 18936          5.0            0.0          0.0   0.0                0.0
# 18937          1.0            2.0          2.0   0.0                0.0
# 18938          2.0            0.0          0.0   0.0                0.0
#
#                     review_headline  \
# 0                        Love this!
# 1                            Love 💕
# 2                        Five Stars
# 3                        Five Stars
# 4                        Five Stars
# ...                             ...
# 18934         Not for bottle liners
# 18935            good enough for me
# 18936                    I love it!
# 18937               save your money
# 18938  Always makes bottles too hot
#
#                                              review_body review_date
# 0      Perfect match for the Gund Huggybuddy I bought...   8/31/2015
# 1             My little girl love this paci contraption!   8/31/2015
# 2      My son loves this one and will only sleep if h...   8/31/2015
# 3                                                Perfect   8/31/2015
# 4                       Amazing addition to the nursery!   8/31/2015
# ...                                                  ...         ...
# 18934  We have been using the bottle warmer and have ...   5/24/2004
# 18935  This isn't the greatest product ever invented,...    4/4/2004
# 18936  I love this bottle warmer.  After researching ...    4/4/2004
# 18937  I finally broke down and opened this shower gi...   12/2/2003
# 18938  We bought this bottle warmer two weeks ago bec...   4/27/2003
#
# [18939 rows x 10 columns]

# %%
# 模糊匹配 清除表中无关的产品 
train=train[train['product_title'].str.contains(product)]
# 日期转换
train.loc[:,'review_date']=pd.to_datetime(train.loc[:,'review_date'],format='%m/%d/%Y', errors='coerce')
# 删除带有空值的行，how='any'只要有一个空值，就删除整行
'''
默认axis=0,how=‘any’,删除带有空值的行，只要有一个空值，就删除整行

axis=1,删除带有空值的列，只要有一个空值，就删除整列

how=‘all’， 整行都是空值时，才会被删除

thresh，设定阈值，缺失值个数大于该阈值，整行(axis=0)或整列(axis=1)才会被删除

subset=[1,2]， 删除指定列（1,2）中包含缺失值的行
'''
train=train.dropna(subset=train.columns,how='any')
# Out:
# C:\Users\14629\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
train
# Out:
#       product_parent                                      product_title  \
# 0          572944212           mary meyer wubbanub plush pacifier, lamb
# 1          911821018                      wubbanub lamb infant pacifier
# 2          392768822                 wubbanub infant pacifier - giraffe
# 3          392768822                 wubbanub infant pacifier - giraffe
# 4          911821018                      wubbanub lamb infant pacifier
# ...              ...                                                ...
# 18934       51313971  munchkin deluxe bottle  and food warmer with p...
# 18935       51313971  munchkin deluxe bottle  and food warmer with p...
# 18936       51313971  munchkin deluxe bottle  and food warmer with p...
# 18937       51313971  munchkin deluxe bottle  and food warmer with p...
# 18938       51313971  munchkin deluxe bottle  and food warmer with p...
#
#        star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0              5.0            0.0          0.0   0.0                1.0
# 1              5.0            0.0          0.0   0.0                1.0
# 2              5.0            0.0          0.0   0.0                1.0
# 3              5.0            0.0          0.0   0.0                1.0
# 4              5.0            0.0          0.0   0.0                1.0
# ...            ...            ...          ...   ...                ...
# 18934          2.0            0.0          0.0   0.0                0.0
# 18935          4.0            1.0          1.0   0.0                0.0
# 18936          5.0            0.0          0.0   0.0                0.0
# 18937          1.0            2.0          2.0   0.0                0.0
# 18938          2.0            0.0          0.0   0.0                0.0
#
#                     review_headline  \
# 0                        Love this!
# 1                            Love 💕
# 2                        Five Stars
# 3                        Five Stars
# 4                        Five Stars
# ...                             ...
# 18934         Not for bottle liners
# 18935            good enough for me
# 18936                    I love it!
# 18937               save your money
# 18938  Always makes bottles too hot
#
#                                              review_body review_date
# 0      Perfect match for the Gund Huggybuddy I bought...  2015-08-31
# 1             My little girl love this paci contraption!  2015-08-31
# 2      My son loves this one and will only sleep if h...  2015-08-31
# 3                                                Perfect  2015-08-31
# 4                       Amazing addition to the nursery!  2015-08-31
# ...                                                  ...         ...
# 18934  We have been using the bottle warmer and have ...  2004-05-24
# 18935  This isn't the greatest product ever invented,...  2004-04-04
# 18936  I love this bottle warmer.  After researching ...  2004-04-04
# 18937  I finally broke down and opened this shower gi...  2003-12-02
# 18938  We bought this bottle warmer two weeks ago bec...  2003-04-27
#
# [11049 rows x 10 columns]

# %%
df1=train.groupby(["product_parent"],sort=True).size().reset_index(name='total_rates_count')

# %%
df1
# Out:
#      product_parent  total_rates_count
# 0           4792175                 14
# 1          12142513                  1
# 2          13588167                  1
# 3          21803708                 27
# 4          22842035                  1
# ..              ...                ...
# 295       985792211                  1
# 296       986016545                 54
# 297       995615099                 12
# 298       996130662                 42
# 299       997127233                 90
#
# [300 rows x 2 columns]

# %%
df2=train.groupby(["product_parent",'star_rating'],sort=True).size().reset_index(name='stars_rate_count')
df2
# Out:
#       product_parent  star_rating  stars_rate_count
# 0            4792175          5.0                14
# 1           12142513          4.0                 1
# 2           13588167          2.0                 1
# 3           21803708          2.0                 1
# 4           21803708          3.0                 2
# ...              ...          ...               ...
# 1015       997127233          1.0                 3
# 1016       997127233          2.0                 3
# 1017       997127233          3.0                 4
# 1018       997127233          4.0                 9
# 1019       997127233          5.0                71
#
# [1020 rows x 3 columns]

# %%
merge12 = pd.merge(df1, df2, on='product_parent', how='outer')
merge12
# Out:
#       product_parent  total_rates_count  star_rating  stars_rate_count
# 0            4792175                 14          5.0                14
# 1           12142513                  1          4.0                 1
# 2           13588167                  1          2.0                 1
# 3           21803708                 27          2.0                 1
# 4           21803708                 27          3.0                 2
# ...              ...                ...          ...               ...
# 1015       997127233                 90          1.0                 3
# 1016       997127233                 90          2.0                 3
# 1017       997127233                 90          3.0                 4
# 1018       997127233                 90          4.0                 9
# 1019       997127233                 90          5.0                71
#
# [1020 rows x 4 columns]

# %%
# 计算每种商品的每一级评价的比例
merge12['rate_ratio']=merge12['stars_rate_count']/merge12['total_rates_count']
# merge12=merge12.set_index(['product_parent','star_rating'])
merge12
# Out:
#       product_parent  total_rates_count  star_rating  stars_rate_count  \
# 0            4792175                 14          5.0                14
# 1           12142513                  1          4.0                 1
# 2           13588167                  1          2.0                 1
# 3           21803708                 27          2.0                 1
# 4           21803708                 27          3.0                 2
# ...              ...                ...          ...               ...
# 1015       997127233                 90          1.0                 3
# 1016       997127233                 90          2.0                 3
# 1017       997127233                 90          3.0                 4
# 1018       997127233                 90          4.0                 9
# 1019       997127233                 90          5.0                71
#
#       rate_ratio
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       0.037037
# 4       0.074074
# ...          ...
# 1015    0.033333
# 1016    0.033333
# 1017    0.044444
# 1018    0.100000
# 1019    0.788889
#
# [1020 rows x 5 columns]

# %%
# 描述性统计，查看商品整体的评价比例
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 统计每条评价的”有用“投票比例
# 将缺失值填充为0
train['helpful_votes'].fillna(0)
train['total_votes'].fillna(0)
train['helpful_rate']=train['helpful_votes']/train['total_votes']
train.sort_values(by='helpful_rate',ascending=False)
# Out:
#       product_parent                                      product_title  \
# 12275      450475749                     wubbanub brown monkey pacifier
# 11940       24160750  nuk 2 pack classic silicone bpa free fashion p...
# 12048      892018890  mam night orthodontic pacifier, boy, 0-6 plus ...
# 12044      671647927             safety 1st pacifier medicine dispenser
# 12043      981045906                    personalized pacifiers pacifier
# ...              ...                                                ...
# 18804      957640647  dexbaby womb sounds bear audio pacifier, brown...
# 18932       51313971  munchkin deluxe bottle  and food warmer with p...
# 18934       51313971  munchkin deluxe bottle  and food warmer with p...
# 18936       51313971  munchkin deluxe bottle  and food warmer with p...
# 18938       51313971  munchkin deluxe bottle  and food warmer with p...
#
#        star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 12275          5.0            1.0          1.0   0.0                1.0
# 11940          2.0            2.0          2.0   0.0                1.0
# 12048          5.0            1.0          1.0   0.0                1.0
# 12044          1.0            1.0          1.0   0.0                0.0
# 12043          5.0            2.0          2.0   0.0                1.0
# ...            ...            ...          ...   ...                ...
# 18804          5.0            0.0          0.0   0.0                0.0
# 18932          5.0            0.0          0.0   0.0                0.0
# 18934          2.0            0.0          0.0   0.0                0.0
# 18936          5.0            0.0          0.0   0.0                0.0
# 18938          2.0            0.0          0.0   0.0                0.0
#
#                                          review_headline  \
# 12275                                     Handy and cute
# 11940                     not for babies with big cheeks
# 12048                                         Love these
# 12044                                          Not good!
# 12043  the color may appear a little different in per...
# ...                                                  ...
# 18804                                     wonderful bear
# 18932                            Excellent Bottle Warmer
# 18934                              Not for bottle liners
# 18936                                         I love it!
# 18938                       Always makes bottles too hot
#
#                                              review_body review_date  \
# 12275  Worked wonderfully for keeping pacifier in bab...  2013-11-27
# 11940  My baby loves this pacifer but I don't give it...  2013-12-27
# 12048  It glows at night so you don't have to turn on...  2013-12-13
# 12044  The npple is very hard!  My daughter did not l...  2013-12-13
# 12043  its cute! its not exactly the same color as sh...  2013-12-13
# ...                                                  ...         ...
# 18804  excellent addition to any baby's nursery. the ...  2007-06-27
# 18932  We registered for this gift after reading the ...  2005-02-06
# 18934  We have been using the bottle warmer and have ...  2004-05-24
# 18936  I love this bottle warmer.  After researching ...  2004-04-04
# 18938  We bought this bottle warmer two weeks ago bec...  2003-04-27
#
#        helpful_rate
# 12275           1.0
# 11940           1.0
# 12048           1.0
# 12044           1.0
# 12043           1.0
# ...             ...
# 18804           NaN
# 18932           NaN
# 18934           NaN
# 18936           NaN
# 18938           NaN
#
# [11049 rows x 11 columns]

# %%
# 将评价标题和正文内容连起来
train['review_headline_body']=train['review_headline']+train['review_body']
train=train.fillna(0)
train
# 输出清洁完毕的数据
# train.to_csv('cleaned_'+product+'.csv')
# Out:
#        product_parent                                      product_title  \
# 0           572944212           mary meyer wubbanub plush pacifier, lamb
# 1           911821018                      wubbanub lamb infant pacifier
# 2           392768822                 wubbanub infant pacifier - giraffe
# 3           392768822                 wubbanub infant pacifier - giraffe
# 4           911821018                      wubbanub lamb infant pacifier
# ...               ...                                                ...
# 18934        51313971  munchkin deluxe bottle  and food warmer with p...
# 18935        51313971  munchkin deluxe bottle  and food warmer with p...
# 18936        51313971  munchkin deluxe bottle  and food warmer with p...
# 18937        51313971  munchkin deluxe bottle  and food warmer with p...
# 18938        51313971  munchkin deluxe bottle  and food warmer with p...
#
#        star_rating  helpful_votes  total_votes  vine  verified_purchase  \
# 0              5.0            0.0          0.0   0.0                1.0
# 1              5.0            0.0          0.0   0.0                1.0
# 2              5.0            0.0          0.0   0.0                1.0
# 3              5.0            0.0          0.0   0.0                1.0
# 4              5.0            0.0          0.0   0.0                1.0
# ...            ...            ...          ...   ...                ...
# 18934          2.0            0.0          0.0   0.0                0.0
# 18935          4.0            1.0          1.0   0.0                0.0
# 18936          5.0            0.0          0.0   0.0                0.0
# 18937          1.0            2.0          2.0   0.0                0.0
# 18938          2.0            0.0          0.0   0.0                0.0
#
#                     review_headline  \
# 0                        Love this!
# 1                            Love 💕
# 2                        Five Stars
# 3                        Five Stars
# 4                        Five Stars
# ...                             ...
# 18934         Not for bottle liners
# 18935            good enough for me
# 18936                    I love it!
# 18937               save your money
# 18938  Always makes bottles too hot
#
#                                              review_body review_date  \
# 0      Perfect match for the Gund Huggybuddy I bought...  2015-08-31
# 1             My little girl love this paci contraption!  2015-08-31
# 2      My son loves this one and will only sleep if h...  2015-08-31
# 3                                                Perfect  2015-08-31
# 4                       Amazing addition to the nursery!  2015-08-31
# ...                                                  ...         ...
# 18934  We have been using the bottle warmer and have ...  2004-05-24
# 18935  This isn't the greatest product ever invented,...  2004-04-04
# 18936  I love this bottle warmer.  After researching ...  2004-04-04
# 18937  I finally broke down and opened this shower gi...  2003-12-02
# 18938  We bought this bottle warmer two weeks ago bec...  2003-04-27
#
#        helpful_rate                               review_headline_body
# 0               0.0  Love this!Perfect match for the Gund Huggybudd...
# 1               0.0   Love 💕My little girl love this paci contraption!
# 2               0.0  Five StarsMy son loves this one and will only ...
# 3               0.0                                  Five StarsPerfect
# 4               0.0         Five StarsAmazing addition to the nursery!
# ...             ...                                                ...
# 18934           0.0  Not for bottle linersWe have been using the bo...
# 18935           1.0  good enough for meThis isn't the greatest prod...
# 18936           0.0  I love it!I love this bottle warmer.  After re...
# 18937           1.0  save your moneyI finally broke down and opened...
# 18938           0.0  Always makes bottles too hotWe bought this bot...
#
# [11049 rows x 12 columns]

# %% [markdown]
# # 分类

# %%
import pandas as pd
product='pacifier'#hair_dryer microwave pacifier
df = pd.read_csv('cleaned_'+product+'.csv', header=0,index_col=0)

# %%
senti=df
# Classifying text based on sentiments(positive or negative)
#  4 5为pos，1 2 3为neg
senti["senti"] = senti["star_rating"]>=4
senti["senti"] = senti["senti"].replace([True , False] , ["pos" , "neg"])

# %%
senti.head()# 读取前五行
# Out:
#    product_parent                             product_title  star_rating  \
# 0       572944212  mary meyer wubbanub plush pacifier, lamb          5.0
# 1       911821018             wubbanub lamb infant pacifier          5.0
# 2       392768822        wubbanub infant pacifier - giraffe          5.0
# 3       392768822        wubbanub infant pacifier - giraffe          5.0
# 4       911821018             wubbanub lamb infant pacifier          5.0
#
#    helpful_votes  total_votes  vine  verified_purchase review_headline  \
# 0            0.0          0.0   0.0                1.0      Love this!
# 1            0.0          0.0   0.0                1.0          Love 💕
# 2            0.0          0.0   0.0                1.0      Five Stars
# 3            0.0          0.0   0.0                1.0      Five Stars
# 4            0.0          0.0   0.0                1.0      Five Stars
#
#                                          review_body review_date  \
# 0  Perfect match for the Gund Huggybuddy I bought...  2015-08-31
# 1         My little girl love this paci contraption!  2015-08-31
# 2  My son loves this one and will only sleep if h...  2015-08-31
# 3                                            Perfect  2015-08-31
# 4                   Amazing addition to the nursery!  2015-08-31
#
#    helpful_rate                               review_headline_body senti
# 0           0.0  Love this!Perfect match for the Gund Huggybudd...   pos
# 1           0.0   Love 💕My little girl love this paci contraption!   pos
# 2           0.0  Five StarsMy son loves this one and will only ...   pos
# 3           0.0                                  Five StarsPerfect   pos
# 4           0.0         Five StarsAmazing addition to the nursery!   pos

# %%
#Count of reviews based on sentiments
senti["senti"].value_counts().plot.bar(color=['green', 'blue'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 去除无关的标点符号，将字母统一转换为小写

# %%
# 将标点符号用空格替换
import re
cleanup_re = re.compile('[^a-z]+')# 不包含 小写字母的bai字符匹配

# %%
def cleanup(sentence):
    sentence = str(sentence)
    sentence = sentence.lower()
    sentence = cleanup_re.sub(' ', sentence).strip()# strip()删除字符串头尾的字符
    #sentence = " ".join(nltk.word_tokenize(sentence))
    return sentence

# %%
senti.head()
# Out:
#    product_parent                             product_title  star_rating  \
# 0       572944212  mary meyer wubbanub plush pacifier, lamb          5.0
# 1       911821018             wubbanub lamb infant pacifier          5.0
# 2       392768822        wubbanub infant pacifier - giraffe          5.0
# 3       392768822        wubbanub infant pacifier - giraffe          5.0
# 4       911821018             wubbanub lamb infant pacifier          5.0
#
#    helpful_votes  total_votes  vine  verified_purchase review_headline  \
# 0            0.0          0.0   0.0                1.0      Love this!
# 1            0.0          0.0   0.0                1.0          Love 💕
# 2            0.0          0.0   0.0                1.0      Five Stars
# 3            0.0          0.0   0.0                1.0      Five Stars
# 4            0.0          0.0   0.0                1.0      Five Stars
#
#                                          review_body review_date  \
# 0  Perfect match for the Gund Huggybuddy I bought...  2015-08-31
# 1         My little girl love this paci contraption!  2015-08-31
# 2  My son loves this one and will only sleep if h...  2015-08-31
# 3                                            Perfect  2015-08-31
# 4                   Amazing addition to the nursery!  2015-08-31
#
#    helpful_rate                               review_headline_body senti
# 0           0.0  Love this!Perfect match for the Gund Huggybudd...   pos
# 1           0.0   Love 💕My little girl love this paci contraption!   pos
# 2           0.0  Five StarsMy son loves this one and will only ...   pos
# 3           0.0                                  Five StarsPerfect   pos
# 4           0.0         Five StarsAmazing addition to the nursery!   pos

# %%
senti["Summary_Clean"] = senti["review_headline_body"].apply(cleanup)
senti.head()
# Out:
#    product_parent                             product_title  star_rating  \
# 0       572944212  mary meyer wubbanub plush pacifier, lamb          5.0
# 1       911821018             wubbanub lamb infant pacifier          5.0
# 2       392768822        wubbanub infant pacifier - giraffe          5.0
# 3       392768822        wubbanub infant pacifier - giraffe          5.0
# 4       911821018             wubbanub lamb infant pacifier          5.0
#
#    helpful_votes  total_votes  vine  verified_purchase review_headline  \
# 0            0.0          0.0   0.0                1.0      Love this!
# 1            0.0          0.0   0.0                1.0          Love 💕
# 2            0.0          0.0   0.0                1.0      Five Stars
# 3            0.0          0.0   0.0                1.0      Five Stars
# 4            0.0          0.0   0.0                1.0      Five Stars
#
#                                          review_body review_date  \
# 0  Perfect match for the Gund Huggybuddy I bought...  2015-08-31
# 1         My little girl love this paci contraption!  2015-08-31
# 2  My son loves this one and will only sleep if h...  2015-08-31
# 3                                            Perfect  2015-08-31
# 4                   Amazing addition to the nursery!  2015-08-31
#
#    helpful_rate                               review_headline_body senti  \
# 0           0.0  Love this!Perfect match for the Gund Huggybudd...   pos
# 1           0.0   Love 💕My little girl love this paci contraption!   pos
# 2           0.0  Five StarsMy son loves this one and will only ...   pos
# 3           0.0                                  Five StarsPerfect   pos
# 4           0.0         Five StarsAmazing addition to the nursery!   pos
#
#                                        Summary_Clean
# 0  love this perfect match for the gund huggybudd...
# 1     love my little girl love this paci contraption
# 2  five starsmy son loves this one and will only ...
# 3                                  five starsperfect
# 4          five starsamazing addition to the nursery

# %% [markdown]
# ## 分训练集和测试集

# %%
split = senti[["Summary_Clean" , "senti"]]
split.head()
# Out:
#                                        Summary_Clean senti
# 0  love this perfect match for the gund huggybudd...   pos
# 1     love my little girl love this paci contraption   pos
# 2  five starsmy son loves this one and will only ...   pos
# 3                                  five starsperfect   pos
# 4          five starsamazing addition to the nursery   pos

# %%
train=split.sample(frac=0.8,random_state=200)#frac=0.8，抽取其中80%。使用random_state，以确保可重复性的例子
train["words"] = train["Summary_Clean"].str.split()
train
# Out:
#                                            Summary_Clean senti  \
# 7510                                 five starsvery cute   pos
# 1179   favorite these are my baby s favorite she has ...   pos
# 2291                    five starsgreat baby shower gift   pos
# 12897  the chomp the chomp baby pacifier is hilarious...   pos
# 8025                                  five starstoo cute   pos
# ...                                                  ...   ...
# 17036  didn t end up working outokay so on the cute f...   neg
# 8246   five starsit was a baby gift and it a cute pac...   pos
# 2325                                        five starsok   pos
# 12046  loved product not packagingvery cute but packa...   neg
# 3040   bunny wubnubmy twin greatfrandbaby that lives ...   pos
#
#                                                    words
# 7510                             [five, starsvery, cute]
# 1179   [favorite, these, are, my, baby, s, favorite, ...
# 2291              [five, starsgreat, baby, shower, gift]
# 12897  [the, chomp, the, chomp, baby, pacifier, is, h...
# 8025                              [five, starstoo, cute]
# ...                                                  ...
# 17036  [didn, t, end, up, working, outokay, so, on, t...
# 8246   [five, starsit, was, a, baby, gift, and, it, a...
# 2325                                     [five, starsok]
# 12046  [loved, product, not, packagingvery, cute, but...
# 3040   [bunny, wubnubmy, twin, greatfrandbaby, that, ...
#
# [8839 rows x 3 columns]

# %%
test=split.drop(train.index)
test["words"] = test["Summary_Clean"].str.split()
test
# Out:
#                                            Summary_Clean senti  \
# 2      five starsmy son loves this one and will only ...   pos
# 3                                      five starsperfect   pos
# 5          five starsgreat breathable and basic pacifier   pos
# 17                                        five starsgood   pos
# 46                        five starsworks like it should   pos
# ...                                                  ...   ...
# 18756  this is the best there is not a cuter more dur...   pos
# 18759  would be great except for snapit s a nice pouc...   neg
# 18760  better than all the rest this is the best paci...   pos
# 18818  we loved the mommy bearwe recieved this as a g...   pos
# 18823  soothing and effectivethe womb sounds bear has...   pos
#
#                                                    words
# 2      [five, starsmy, son, loves, this, one, and, wi...
# 3                                   [five, starsperfect]
# 5      [five, starsgreat, breathable, and, basic, pac...
# 17                                     [five, starsgood]
# 46                  [five, starsworks, like, it, should]
# ...                                                  ...
# 18756  [this, is, the, best, there, is, not, a, cuter...
# 18759  [would, be, great, except, for, snapit, s, a, ...
# 18760  [better, than, all, the, rest, this, is, the, ...
# 18818  [we, loved, the, mommy, bearwe, recieved, this...
# 18823  [soothing, and, effectivethe, womb, sounds, be...
#
# [2210 rows x 3 columns]

# %% [markdown]
# ## 构建计数器和测试的TFIDF向量   训练和测试数据

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

# %%
stopwords = [
    "a", "about", "above", "across", "after", "afterwards", "again", "against",
    "all", "almost", "alone", "along", "already", "also", "although", "always",
    "am", "among", "amongst", "amoungst", "amount", "an", "and", "another",
    "any", "anyhow", "anyone", "anything", "anyway", "anywhere", "are",
    "around", "as", "at", "back", "be", "became", "because", "become",
    "becomes", "becoming", "been", "before", "beforehand", "behind", "being",
    "below", "beside", "besides", "between", "beyond", "bill", "both",
    "bottom", "but", "by", "call", "can", "cannot", "cant", "co", "con",
    "could", "couldnt", "cry", "de", "describe", "detail", "do", "done",
    "down", "due", "during", "each", "eg", "eight", "either", "eleven", "else",
    "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone",
    "everything", "everywhere", "except", "few", "fifteen", "fifty", "fill",
    "find", "fire", "first", "five", "for", "former", "formerly", "forty",
    "found", "four", "from", "front", "full", "further", "get", "give", "go",
    "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter",
    "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his",
    "how", "however", "hundred", "i", "ie", "if", "in", "inc", "indeed",
    "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter",
    "latterly", "least", "less", "ltd", "made", "many", "may", "me",
    "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly",
    "move", "much", "must", "my", "myself", "name", "namely", "neither",
    "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone",
    "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on",
    "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our",
    "ours", "ourselves", "out", "over", "own", "part", "per", "perhaps",
    "please", "put", "rather", "re", "same", "see", "seem", "seemed",
    "seeming", "seems", "serious", "several", "she", "should", "show", "side",
    "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone",
    "something", "sometime", "sometimes", "somewhere", "still", "such",
    "system", "take", "ten", "than", "that", "the", "their", "them",
    "themselves", "then", "thence", "there", "thereafter", "thereby",
    "therefore", "therein", "thereupon", "these", "they", "thick", "thin",
    "third", "this", "those", "though", "three", "through", "throughout",
    "thru", "thus", "to", "together", "too", "top", "toward", "towards",
    "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us",
    "very", "via", "was", "we", "well", "were", "what", "whatever", "when",
    "whence", "whenever", "where", "whereafter", "whereas", "whereby",
    "wherein", "whereupon", "wherever", "whether", "which", "while", "whither",
    "who", "whoever", "whole", "whom", "whose", "why", "will", "with",
    "within", "without", "would", "yet", "you", "your", "yours", "yourself",
    "yourselves",'one','two','three','four','five','baby', 'boy', 'buy', 'come',
    'daughter', 'exactly', 'favorite', 'friend', 'good', 'great','item', 'just',
    'kid', 'like', 'love', 'make', 'month', 'newborn', 'paci', 'pacifier', 'pacis', 
    'receive', 'recommend', 'son', 'starsgreat', 'starslove','try', 'use',  'wubbanub']

tfidf_transformer = TfidfTransformer()#  TfidfVectorizer 完成向量化与 TF-IDF 预处理
# CountVectorizer会将文本中的词语转换为词频矩阵，它通过fit_transform函数计算各个词语出现的次数。
'''
ngram_range：例如ngram_range(min,max)，是指将text分成min，min+1，min+2,.........max 个不同的词组。
比如 '我 爱 中国' 中ngram_range(1,3)之后可得到'我'  '爱'  '中国'  '我 爱'  '爱 中国' 和'我 爱 中国'，
如果是ngram_range (1,1) 则只能得到单个单词'我'  '爱'和'中国'。
'''
count_vect = CountVectorizer(min_df=2 ,stop_words=stopwords ,
                             ngram_range=(1,2))
X_train_counts = count_vect.fit_transform(train["Summary_Clean"])        
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_new_counts = count_vect.transform(test["Summary_Clean"])
X_test_tfidf = tfidf_transformer.transform(X_new_counts)

# %%
#print(X_train_counts)#第0个列表元素，**词典中索引为3666的元素**， 词频(在此句中词出现次数)
#print(X_train_tfidf)#  TfidfVectorizer 完成向量化与 TF-IDF 预处理
